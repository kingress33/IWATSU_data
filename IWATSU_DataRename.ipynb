# %% [markdown]
# <!-- # %% [markdown]
# # ### 檔案命名
# # 功能：
# # 1. 依檔名或欄位把檔案分進 waveforms/ summary/ images/
# # 2. 只對 summary/ 下的 CSV 進行標準化重新命名
# # 命名規則：
# # <vendor>_<material>_<size>_<AC/DC>_<SIN/PULSE>_<freq>k_<ΔB/Bmax>_[Dxx]_[HdcAm]_[temp]_[sample]_N=<turn ratio>.csv -->

# %% [markdown]
# ### 檔案命名
# 功能：
# 1. 依檔名或欄位把檔案分進 waveforms/ summary/ images/
# 2. 只對 summary/ 下的 CSV 進行標準化重新命名
# ### 命名規則：
# <vendor>_<material>_<size>_<AC/DC>_<SIN/PULSE>_<freq>k_<ΔB 或 Bmax>_
# [Dxx]_[temp]_[sample]_N=<turn ratio>.csv

# %%
# 清空所有變數
# %reset -f  
# 強制 Python 回收記憶體
import gc
gc.collect()
# Out:
# 0

# %%
import os
import re
import shutil
import sys
import pandas as pd
from typing import Dict, Optional

# %%
"""
DATE:

250328
250416
250423
250502-s1
250502-s2
250514
"""
# Out:
# '\nDATE:\n\n250328\n250416\n250423\n250502-s1\n250502-s2\n250514\n'

# %% [markdown]
# ### 使用者直接 Key 的參數

# %%
# ─── 使用者直接 Key 的參數（改這裡就好）─────────────────────────────
USER_DATE = "250328"
USER_VENDOR = "CSC"  # 廠商
USER_MAT = "HighFlux"  # 材料
USER_SIZE = "CH467160G"  # 尺寸
USER_SAMPLE = "A"  # A / B / C… 沒有就留空
USER_TEMP = "25"  # 溫度（°C）
COPY_INSTEAD_OF_MOVE = True  # True=複製，False=移動
# ────────────────────────────────────────────────────────────────

SCRIPT_DIR = os.path.dirname(
    __file__) if "__file__" in globals() else os.getcwd()
RENAME_D = os.path.join(SCRIPT_DIR, "RENAME")
os.makedirs(RENAME_D, exist_ok=True)

# 設定分類資料夾
root = os.path.join(".", USER_DATE)
wave_d = os.path.normpath(f"{USER_DATE}/waveforms")
summ_d = os.path.normpath(f"{USER_DATE}/summary")
img_d = os.path.normpath(f"{USER_DATE}/images")
for d in (wave_d, summ_d, img_d):
    os.makedirs(d, exist_ok=True)

# ---------- 可調整：CSV 欄位對應表 ----------
COLUMN_MAP: Dict[str, list[str]] = {
    "mode": ["mode"],
    "function": ["function", "waveform"],
    "freq": ["freq(kHz)", "frequency(kHz)"],
    "deltaB": ["fix value"],
    "duty": ["Duty(%)"],
    "hdc": ["Hdc(A/m)"],
    "n1": ["N1"],  # 新增 N1 欄位
    "n2": ["N2"],  # 新增 N2 欄位
}


# ---------- 小工具：安全提取欄位值 ----------
def safe_get(df: pd.DataFrame, key: str, default: str = "") -> str:
    col = find_col(df, key)
    if col is not None and not df[col].empty:
        return str(df[col].iloc[0])
    return default


# ---------- 小工具：找欄位名稱 ----------
def find_col(df: pd.DataFrame, key: str) -> Optional[str]:
    for col in df.columns:
        if col.strip().lower() in [c.lower() for c in COLUMN_MAP[key]]:
            return col
    return None


# ---------- Duty 標籤 ----------
def duty_tag(duty_val: str, func: str) -> str:
    # 僅在 PULSE 模式下檢查 Duty
    if func != "pulse":
        return ""
    try:
        d = float(duty_val) / 100  # Duty(%) 轉為小數
        return "" if abs(d - 0.5) < 1e-2 else f"D{d:.1f}"  # 保留一位小數
    except Exception:
        return ""


# ---------- Hdc 標籤 ----------
def hdc_tag(df: pd.DataFrame, acdc: str) -> str:
    # 僅在 DC 模式下顯示 Hdc
    if acdc != "DC":
        return ""
    try:
        # 提取 Hdc(A/m) 欄位
        col = find_col(df, "hdc")
        if col is None:
            return ""
        # 將欄位值轉為數值，無效值轉為 NaN
        hdc_vals = pd.to_numeric(df[col], errors='coerce').abs()
        # 移除 NaN 值
        hdc_vals = hdc_vals.dropna()
        # 檢查是否有有效數據
        if hdc_vals.empty:
            return ""
        # 生成範圍標籤
        hdc_tag = f"{int(hdc_vals.min())}-{int(hdc_vals.max())}Am"
        return hdc_tag
    except Exception:
        return ""


# ---------- 從 N1 和 N2 欄位提取圈數比例，轉成 N=x.y ----------
def get_turns_ratio(df: pd.DataFrame) -> str:
    try:
        # 提取 N1 和 N2
        n1 = safe_get(df, "n1", "1")  # 預設為 1
        n2 = safe_get(df, "n2", "1")  # 預設為 1
        # 轉為整數
        p = int(float(n1))  # primary turns
        s = int(float(n2))  # secondary turns
        # 生成 N=x.y 格式
        if p == s:
            return f"N={p}"
        return f"N={p}.{s}"
    except Exception:
        return "N=1"  # 如果提取或轉換失敗，預設為 N=1


# =================重新命名流程=================


def rename_summary(csv_path: str) -> None:
    print(f"正在處理檔案：{csv_path}")
    # 檢查檔案是否為空
    if os.path.getsize(csv_path) == 0:
        print(f"警告：{csv_path} 檔案為空，跳過處理")
        return

    # 嘗試讀取檔案
    try:
        df = pd.read_csv(csv_path, skiprows=3, encoding='big5')
    except UnicodeDecodeError as e:
        print(f"編碼錯誤：{csv_path} 無法使用 Big5 編碼讀取，錯誤訊息：{e}")
        print("建議：嘗試其他編碼（如 'gbk' 或 'latin1'），或將檔案轉換為 UTF-8")
        return
    except pd.errors.EmptyDataError:
        print(f"錯誤：{csv_path} 檔案內容為空或無數據，無法處理")
        return
    except Exception as e:
        print(f"讀取檔案失敗：{csv_path}，錯誤訊息：{e}")
        return

    base, ext = os.path.splitext(os.path.basename(csv_path))

    # 提取 mode 並判斷 AC/DC
    mode_raw = safe_get(df, "mode").strip().upper()
    if not mode_raw:
        print("警告：mode 值為空，預設為 AC")
        acdc = "AC"
    else:
        # 更明確的判斷邏輯
        if mode_raw == "DC_BIAS" or "DC" in mode_raw:
            acdc = "DC"
        elif mode_raw == "STANDARD":
            acdc = "AC"
        else:
            print(f"警告：無法識別 mode 值 '{mode_raw}'，預設為 AC")
            acdc = "AC"
    print(f"提取 mode：{mode_raw}，判斷為 {acdc}")

    # 提取波形類型
    func_raw = safe_get(df, "function").upper()
    func = "sin" if func_raw.startswith("SIN") else "pulse"
    print(f"提取 function：{func_raw}，判斷為 {func}")

    # 提取頻率
    freq = int(round(float(safe_get(df, "freq", "0"))))
    print(f"提取 freq：{freq}kHz")

    # ΔB / Bmax 處理
    try:
        b_vals = df[find_col(df, "deltaB")].abs()  # 單位從 T 轉為 mT
        b_tag = f"Bm{int(b_vals.min())}-{int(b_vals.max())}mT" if acdc == "AC" else f"dB{int(b_vals.mean())}mT"
        print(f"提取 deltaB：{b_vals.min()} - {b_vals.max()}，生成標籤：{b_tag}")
    except Exception as e:
        print(f"處理 deltaB 失敗：{csv_path}，錯誤訊息：{e}")
        return

    # Duty 標籤
    duty = duty_tag(safe_get(df, "duty"), func)
    print(f"提取 duty：{duty}")

    # Hdc 標籤（範圍形式）
    hdc = hdc_tag(df, acdc)
    print(f"提取 Hdc：{hdc}")

    # 圈數（從 N1 和 N2 提取）
    turns = get_turns_ratio(df)
    print(f"提取 turns：{turns}")

    # 溫度標籤
    temp_tag = f"{USER_TEMP}C" if USER_TEMP else ""
    print(f"溫度標籤：{temp_tag}")

    # 組合檔名
    parts = [
        USER_VENDOR, USER_MAT, USER_SIZE, acdc, func, f"{freq}k", b_tag, duty,
        hdc, temp_tag,
        USER_SAMPLE.upper(), turns
    ]
    new_name = "_".join([p for p in parts if p]) + ext
    new_path = os.path.join(RENAME_D, new_name)

    if COPY_INSTEAD_OF_MOVE:
        shutil.copy2(csv_path, new_path)
        action = "Copy"
    else:
        shutil.move(csv_path, new_path)
        action = "Move"
    print(f"✔ {action:4} {base+ext} → RENAME/{new_name}")


# =================分類+重命名流程=================


def classify_and_rename():
    # 分類檔案（僅針對不在 waveforms/、summary/、images/ 資料夾中的檔案）
    files_classified = 0
    for r, _, fs in os.walk(root):
        for f in fs:
            p = os.path.normpath(os.path.join(r, f))
            # 檢查檔案是否已經在目標資料夾中
            if p.startswith((wave_d, summ_d, img_d)):
                print(f"跳過檔案：{p}，因為已經在目標資料夾中")
                continue
            if f.endswith("_Norm..csv"):
                # if f.endswith("_Norm.csv"):
                dest = os.path.join(wave_d, f)
            elif f.lower().endswith(".csv"):
                dest = os.path.join(summ_d, f)
            elif f.lower().endswith(".jpg"):
                dest = os.path.join(img_d, f)
            else:
                print(f"跳過檔案：{p}，因為不符合分類條件")
                continue
            shutil.move(p, dest)
            print(f"✔ Classified: {f} → {dest}")
            files_classified += 1
    if files_classified == 0:
        print("分類階段：未找到需要分類的檔案，所有檔案可能已經分類好")

    # 重新命名 summary/ 下的 CSV
    if not os.path.exists(summ_d):
        print(f"錯誤：{summ_d} 資料夾不存在，無法進行重新命名！")
        sys.exit(1)

    csv_files = [f for f in os.listdir(summ_d) if f.lower().endswith(".csv")]
    if not csv_files:
        print(f"警告：{summ_d} 資料夾中未找到任何 CSV 檔案，無法進行重新命名！")
    else:
        print(f"找到 {len(csv_files)} 個 CSV 檔案：{csv_files}")

    for f in csv_files:
        rename_summary(os.path.join(summ_d, f))

    print("🎉 All done! 檔案已分類並複製到 ./RENAME")

# %% [markdown]
# ###　執行結果

# %%
# ---------- 程式進入點 ----------
if __name__ == "__main__":
    classify_and_rename()
# Out:
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_100mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_120mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_140mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_160mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_20mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_40mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_SIN_100k_80mT_N10_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-1_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-2_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-3_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-4_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-5_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-6_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-7_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\images\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL-8_Norm..jpg，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_100mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_120mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_140mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_160mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_20mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_40mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_60mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_SIN_100k_80mT_N10_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL.csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_100mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_120mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_140mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_160mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_20mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_40mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_SIN_100k_80mT_N10_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL-8_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-1_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-2_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-3_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-4_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-5_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-6_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-7_Norm..csv，因為已經在目標資料夾中
# 跳過檔案：250328\waveforms\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL-8_Norm..csv，因為已經在目標資料夾中
# ...
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_100mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：100 - 100，生成標籤：dB100mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_100mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB100mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_120mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：120 - 120，生成標籤：dB120mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_120mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB120mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_140mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：140 - 140，生成標籤：dB140mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_140mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB140mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_160mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：160 - 160，生成標籤：dB160mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_160mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB160mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_20mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：20 - 20，生成標籤：dB20mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_20mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB20mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_40mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：40 - 40，生成標籤：dB40mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_40mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB40mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_60mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：60 - 60，生成標籤：dB60mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_60mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB60mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_SIN_100k_80mT_N10_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：SINE，判斷為 sin
# 提取 freq：100kHz
# 提取 deltaB：80 - 80，生成標籤：dB80mT
# 提取 duty：
# 提取 Hdc：299-2399Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_SIN_100k_80mT_N10_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_sin_100k_dB80mT_299-2399Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：100 - 100，生成標籤：dB100mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_100mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：10 - 10，生成標籤：dB10mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_10mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：10 - 10，生成標籤：dB10mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_10mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：110 - 110，生成標籤：dB110mT
# 提取 duty：D0.4
# 提取 Hdc：200-2000Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_110mT_N10_D0.4_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.4_200-2000Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：110 - 110，生成標籤：dB110mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_110mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：110 - 110，生成標籤：dB110mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_110mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：120 - 120，生成標籤：dB120mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_120mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：130 - 130，生成標籤：dB130mT
# 提取 duty：D0.4
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_130mT_N10_D0.4_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.4_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：130 - 130，生成標籤：dB130mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_130mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：130 - 130，生成標籤：dB130mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_130mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：140 - 140，生成標籤：dB140mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_140mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：140 - 140，生成標籤：dB140mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_140mT_N15_s2_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：150 - 150，生成標籤：dB150mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_150mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：150 - 150，生成標籤：dB150mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_150mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：160 - 160，生成標籤：dB160mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_160mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：170 - 170，生成標籤：dB170mT
# 提取 duty：D0.4
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_170mT_N10_D0.4_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.4_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：170 - 170，生成標籤：dB170mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_170mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：170 - 170，生成標籤：dB170mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_170mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：180 - 180，生成標籤：dB180mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_180mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：190 - 190，生成標籤：dB190mT
# 提取 duty：D0.4
# 提取 Hdc：200-2000Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_190mT_N10_D0.4_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_D0.4_200-2000Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：190 - 190，生成標籤：dB190mT
# 提取 duty：
# 提取 Hdc：200-2000Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_190mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_200-2000Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：190 - 190，生成標籤：dB190mT
# 提取 duty：D0.6
# 提取 Hdc：200-2000Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_190mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_D0.6_200-2000Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：200 - 200，生成標籤：dB200mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_200mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：20 - 20，生成標籤：dB20mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_20mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：20 - 20，生成標籤：dB20mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_20mT_N15_s2_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：30 - 30，生成標籤：dB30mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_30mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：30 - 30，生成標籤：dB30mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_30mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：40 - 40，生成標籤：dB40mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_40mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：50 - 50，生成標籤：dB50mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_50mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：50 - 50，生成標籤：dB50mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_50mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：60 - 60，生成標籤：dB60mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_60mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：60 - 60，生成標籤：dB60mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_60mT_N15_s2_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：70 - 70，生成標籤：dB70mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_70mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：70 - 70，生成標籤：dB70mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_70mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.6_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：80 - 80，生成標籤：dB80mT
# 提取 duty：
# 提取 Hdc：300-2399Am
# 提取 turns：N=15
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_80mT_N15_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_300-2399Am_25C_A_N=15.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：90 - 90，生成標籤：dB90mT
# 提取 duty：D0.4
# 提取 Hdc：200-2000Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_90mT_N10_D0.4_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.4_200-2000Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：90 - 90，生成標籤：dB90mT
# 提取 duty：
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_90mT_N10_D0.5_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_200-2299Am_25C_A_N=10.csv
# 正在處理檔案：250328\summary\CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL.csv
# 提取 mode：DC BIAS，判斷為 DC
# 提取 function：PULSE，判斷為 pulse
# 提取 freq：100kHz
# 提取 deltaB：90 - 90，生成標籤：dB90mT
# 提取 duty：D0.6
# 提取 Hdc：200-2299Am
# 提取 turns：N=10
# 溫度標籤：25C
# ✔ Copy CH467160_DC_TRI_100k_90mT_N10_D0.6_ALL.csv → RENAME/CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.6_200-2299Am_25C_A_N=10.csv
# 🎉 All done! 檔案已分類並複製到 ./RENAME
