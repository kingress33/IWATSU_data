# %% [markdown]
# <!-- # %% [markdown]
# # ### 檔案命名
# # 功能：
# # 1. 依檔名或欄位把檔案分進 waveforms/ summary/ images/
# # 2. 只對 summary/ 下的 CSV 進行標準化重新命名
# # 命名規則：
# # <vendor>_<material>_<size>_<AC/DC>_<SIN/PULSE>_<freq>k_<ΔB/Bmax>_[Dxx]_[HdcAm]_[temp]_[sample]_N=<turn ratio>.csv -->

# %%
import os
import pandas as pd


def count_csv_data(main_folder):
    # 用於儲存總計數據
    total_csv_count = 0
    total_csv_zero = 0
    total_data_rows_all = 0
    summary = []

    # 遍歷主資料夾下的所有子資料夾
    for subfolder in os.listdir(main_folder):
        subfolder_path = os.path.join(main_folder, subfolder)

        # 檢查是否為資料夾
        if os.path.isdir(subfolder_path):
            csv_count = 0
            total_data_rows = 0
            zero_rows_files = []  # 儲存數據量為 0 行的檔案

            print(f"\n子資料夾 {subfolder}:")

            # 遍歷子資料夾內的所有檔案
            for file in os.listdir(subfolder_path):
                if file.endswith('.csv'):
                    csv_count += 1
                    file_path = os.path.join(subfolder_path, file)

                    try:
                        # 嘗試使用 UTF-8 編碼讀取
                        df = pd.read_csv(file_path,
                                         skiprows=4,
                                         encoding='utf-8')
                    except UnicodeDecodeError:
                        # 如果 UTF-8 失敗，嘗試使用 'big5' 編碼（常用於繁體中文）
                        try:
                            df = pd.read_csv(file_path,
                                             skiprows=4,
                                             encoding='big5')
                        except UnicodeDecodeError:
                            # 如果 big5 也失敗，嘗試 'gbk' 編碼（常用於簡體中文）
                            try:
                                df = pd.read_csv(file_path,
                                                 skiprows=4,
                                                 encoding='gbk')
                            except Exception as e:
                                print(f"無法讀取檔案 {file}: {e}")
                                continue

                    # 計算數據量（行數）
                    data_rows = len(df)
                    total_data_rows += data_rows

                    # 檢查數據量是否為 0 點
                    if data_rows == 0:
                        zero_rows_files.append(file)
                        total_csv_zero += 1
                    else:
                        print(f"檔案 {file}: 數據量 = {data_rows} 點")

            # 該子資料夾的統計結果
            print(f"CSV 檔案數量 = {csv_count}")
            print(f"總數據量 = {total_data_rows} 點")

            # 列出數據量為 0 行的檔案
            if zero_rows_files:
                print("數據量為 0 行的檔案：")
                for zero_file in zero_rows_files:
                    print(f"- {zero_file}")
            else:
                print("無數據量為 0 行的檔案")

            print()  # 換行

            # 更新總計
            total_csv_count += csv_count
            total_data_rows_all += total_data_rows
            summary.append((subfolder, csv_count, total_data_rows))

    # 輸出總結報告
    print("=" * 50)
    print("總結報告")
    print("=" * 50)
    print(f"{'子資料夾':<20} {'CSV 數量':<10} {'數據量 (點)':<10}")
    print("-" * 50)
    for subfolder, csv_count, data_rows in summary:
        print(f"{subfolder:<20} {csv_count:<10} {data_rows:<10}")
    print("-" * 50)
    print(f"總計 CSV 檔案數量 = {total_csv_count}")
    print(f"總計數據量為 0 行的檔案 = {total_csv_zero} 個")
    print(f"總計數據量 = {total_data_rows_all} 點")

# %%
if __name__ == "__main__":
    main_folder_path = "./"
    count_csv_data(main_folder_path)
# Out:
# 子資料夾 3C94:
# 檔案 Ferroxcube_3C94_R20-10-7_AC_sin_50k_Bm28-157mT_25C_N=7.csv: 數據量 = 14 點
# CSV 檔案數量 = 1
# 總數據量 = 14 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 CH229060G:
# 檔案 CSC_HighFlux_CH229060G_AC_pulse_100k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_AC_pulse_100k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_100k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_100k_Bm10-145mT_25C_N=14.csv: 數據量 = 27 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_100k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_110k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_150k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_200k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_50k_Bm10-130mT_25C_N=14.csv: 數據量 = 12 點
# 檔案 CSC_HighFlux_CH229060G_AC_sin_90k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB100mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB100mT_D0.2_4654-5819Am_25C_N=14.csv: 數據量 = 2 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB100mT_D0.2_580-4074Am_25C_N=14.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB120mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB150mT_D0.2_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB50mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB50mT_D0.2_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB80mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_pulse_100k_dB83mT_D0.2_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB100mT_0-2116Am_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB100mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB100mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB120mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB150mT_0-2116Am_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB150mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB200mT_0-2116Am_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB50mT_0-2116Am_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB50mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB50mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB80mT_1058-5291Am_25C_N=12.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH229060G_DC_sin_100k_dB83mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# CSV 檔案數量 = 31
# 總數據量 = 317 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 CH229160G:
# 檔案 CSC_HighFlux_CH229160G_AC_sin_110k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229160G_AC_sin_150k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229160G_AC_sin_50k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH229160G_AC_sin_90k_Bm20-200mT_25C_N=12.csv: 數據量 = 20 點
# CSV 檔案數量 = 4
# 總數據量 = 80 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 CH467160G:
# 檔案 CSC_HighFlux_CH467160G_AC_pulse_100k_Bm20-100mT_25C_A_N=10.csv: 數據量 = 16 點
# 檔案 CSC_HighFlux_CH467160G_AC_pulse_100k_Bm20-100mT_25C_B_N=10.csv: 數據量 = 16 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm10-100mT_25C_B_N=10.csv: 數據量 = 18 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm10-105mT_25C_A_N=10.csv: 數據量 = 19 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm20-50mT_25C_A_N=24.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm20-65mT_25C_A_N=20.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm5-100mT_25C_A_N=10.csv: 數據量 = 27 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm5-15mT_25C_A_N=36.csv: 數據量 = 10 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_100k_Bm5-50mT_25C_A_N=4.csv: 數據量 = 17 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_105k_Bm10-100mT_25C_B_N=10.csv: 數據量 = 18 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_105k_Bm10-115mT_25C_A_N=10.csv: 數據量 = 21 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_95k_Bm10-100mT_25C_B_N=10.csv: 數據量 = 18 點
# 檔案 CSC_HighFlux_CH467160G_AC_sin_95k_Bm10-110mT_25C_A_N=10.csv: 數據量 = 20 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.2_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.4_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.4_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.7_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.8_299-2099Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB100mT_D0.8_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_1099-1765Am_25C_A_N=10.csv: 數據量 = 4 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_1199-2399Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.1_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.1_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.2_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.4_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.4_134-2933Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.8_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.9_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB10mT_D0.9_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.4_200-2000Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.4_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB110mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB117mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB120mT_D0.8_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB130mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_300-2399Am_25C_B_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB140mT_D0.8_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB150mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB15mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB15mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB15mT_D0.4_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB15mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB15mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_299-2099Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB160mT_D0.8_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB170mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_299-599Am_25C_A_N=20.csv: 數據量 = 1 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.3_299-2099Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB180mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_200-2000Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_D0.4_200-2000Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB190mT_D0.6_200-2000Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_299-1500Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.3_299-1199Am_25C_A_N=10.csv: 數據量 = 5 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.4_299-1199Am_25C_A_N=10.csv: 數據量 = 5 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.6_299-1500Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB200mT_D0.7_299-1500Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_1199-2399Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_300-2399Am_25C_B_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.1_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.1_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.1_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.2_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.2_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.4_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.6_299-1799Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.6_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.8_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.8_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.8_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.9_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.9_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB20mT_D0.9_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB25mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB25mT_D0.4_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB25mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB25mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.1_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.1_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.2_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.4_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.8_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.9_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB30mT_D0.9_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB35mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB35mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB35mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.1_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.1_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.1_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.1_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.2_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.2_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.4_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.7_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.8_299-2099Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.8_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.8_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.9_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.9_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB40mT_D0.9_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB45mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB45mT_D0.9_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.1_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.2_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.4_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.7_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.8_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB50mT_D0.9_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB55mT_D0.8_100-2199Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_300-2399Am_25C_B_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.1_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.2_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.2_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.4_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.8_299-2099Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.8_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.8_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB60mT_D0.9_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.1_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.2_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.4_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.8_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.8_2399-2399Am_25C_A_N=10.csv: 數據量 = 3 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB70mT_D0.9_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.1_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.2_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.2_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.2_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.3_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.3_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.3_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.4_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.4_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.4_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.4_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.4_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.6_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.6_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.6_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.6_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.7_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.7_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.7_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.7_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.8_299-2099Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.8_299-2398Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.8_300-2399Am_25C_A_N=15.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB80mT_D0.9_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_99-1000Am_25C_A_N=10.csv: 數據量 = 9 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.2_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.3_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.3_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.4_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.4_200-2000Am_25C_A_N=10.csv: 數據量 = 6 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.4_298-2402Am_25C_A_N=30.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.6_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.7_199-2299Am_25C_A_N=20.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.7_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_pulse_100k_dB90mT_D0.8_200-2299Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB100mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB100mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB120mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB140mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB160mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB20mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB40mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB40mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB50mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB60mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB80mT_299-2399Am_25C_A_N=10.csv: 數據量 = 7 點
# 檔案 CSC_HighFlux_CH467160G_DC_sin_100k_dB80mT_299-2399Am_25C_B_N=10.csv: 數據量 = 7 點
# CSV 檔案數量 = 397
# 總數據量 = 2898 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 CS229060:
# 檔案 CSC_Sendust_CS229060_AC_pulse_100k_Bm5-100mT_25C_N=14.csv: 數據量 = 19 點
# 檔案 CSC_Sendust_CS229060_AC_sin_100k_Bm10-120mT_25C_N=14.csv: 數據量 = 22 點
# 檔案 CSC_Sendust_CS229060_AC_sin_100k_Bm5-100mT_25C_N=14.csv: 數據量 = 19 點
# 檔案 CSC_Sendust_CS229060_AC_sin_110k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_AC_sin_150k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_AC_sin_200k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_AC_sin_50k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_AC_sin_90k_Bm10-100mT_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_DC_pulse_100k_dB83mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_DC_sin_100k_dB83mT_580-5819Am_25C_N=14.csv: 數據量 = 9 點
# 檔案 CSC_Sendust_CS229060_DC_sin_500k_dB40mT_580-7407Am_25C_N=14.csv: 數據量 = 10 點
# 檔案 CSC_Sendust_CS229060_DC_sin_500k_dB50mT_580-7407Am_25C_N=14.csv: 數據量 = 10 點
# CSV 檔案數量 = 12
# 總數據量 = 143 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR28:
# 檔案 DMC_DMR28_R25-15-8_AC_sin_100k_Bm250-360mT_100C_N=6.csv: 數據量 = 4 點
# 檔案 DMC_DMR28_R25-15-8_AC_sin_100k_Bm50-360mT_100C_N=6.csv: 數據量 = 8 點
# CSV 檔案數量 = 2
# 總數據量 = 12 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR53:
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_1000k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_1000k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_100k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_100k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_300k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_300k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_500k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_pulse_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_1000k_Bm10-100mT_25C_A_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_1000k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 14 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_1000k_Bm10-200mT_25C_C_N=3.csv: 數據量 = 19 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_3000k_Bm10-50mT_25C_A_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_3000k_Bm10-50mT_25C_B_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_3000k_Bm10-50mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_500k_Bm10-100mT_25C_A_N=3.csv: 數據量 = 24 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_500k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 24 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR53_R12.5-7.5-7_AC_sin_500k_Bm10-260mT_25C_A_N=3.csv: 數據量 = 27 點
# CSV 檔案數量 = 18
# 總數據量 = 215 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR70:
# 檔案 DMC_DMR70_R25-15-8_AC_sin_100k_Bm50-320mT_100C_N=6.csv: 數據量 = 6 點
# CSV 檔案數量 = 1
# 總數據量 = 6 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR91:
# 檔案 DMC_DMR91_R12.7-7.92-6.35P_AC_sin_100k_Bm10-480mT_25C_N=3.csv: 數據量 = 38 點
# 檔案 DMC_DMR91_R12.7-7.92-6.35P_AC_sin_100k_Bm20-420mT_100C_N=3.csv: 數據量 = 20 點
# CSV 檔案數量 = 2
# 總數據量 = 58 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR96A_R12:
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_AC_sin_100k_Bm10-480mT_25C_N=3.csv: 數據量 = 38 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_AC_sin_100k_Bm20-380mT_100C_N=3.csv: 數據量 = 18 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_AC_sin_800k_Bm10-200mT_25C_N=3.csv: 數據量 = 19 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_100k_dB100mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_100k_dB150mT_10-50Am_25C_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_100k_dB200mT_10-50Am_25C_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_100k_dB50mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_50k_dB100mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_50k_dB125mT_0-0Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_50k_dB150mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_50k_dB150mT_10-50Am_25C_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR96A_R12.7-7.92-6.35P_DC_sin_50k_dB50mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# CSV 檔案數量 = 12
# 總數據量 = 139 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 DMR96A_R49:
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_100k_dB100mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_100k_dB145mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_100k_dB200mT_10-50Am_25C_N=3.csv: 數據量 = 4 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_100k_dB50mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_50k_dB100mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_50k_dB125mT_0-0Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_50k_dB150mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_50k_dB200mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# 檔案 DMC_DMR96A_R49-31.8-19P_DC_sin_50k_dB50mT_10-100Am_25C_N=3.csv: 數據量 = 9 點
# CSV 檔案數量 = 9
# 總數據量 = 74 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 ML91S:
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_A_N=2.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_1000k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 23 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_100k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_300k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_360k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_360k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_A_N=1.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_A_N=2.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_A_N=3.csv: 數據量 = 19 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 29 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_pulse_500k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 35 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_1000k_Bm10-120mT_25C_C_N=3.csv: 數據量 = 16 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_2000k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_3000k_Bm10-50mT_25C_C_N=3.csv: 數據量 = 4 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_3000k_Bm10-70mT_25C_A_N=3.csv: 數據量 = 6 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 24 點
# 檔案 HITACHI_ML91S_R14-07-05_AC_sin_500k_Bm10-120mT_25C_C_N=3.csv: 數據量 = 11 點
# CSV 檔案數量 = 20
# 總數據量 = 270 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 ML95S:
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_B_N=1.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_B_N=2.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_1000k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 19 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_1000k_Bm5-100mT_25C_A_N=3.csv: 數據量 = 19 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_100k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 19 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_300k_Bm10-100mT_25C_A_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_A_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_B_N=1.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_B_N=2.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 29 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_pulse_500k_Bm5-100mT_25C_A_N=3.csv: 數據量 = 40 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_1000k_Bm10-110mT_25C_A_N=3.csv: 數據量 = 10 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_1000k_Bm5-100mT_25C_A_N=3.csv: 數據量 = 38 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_1500k_Bm10-80mT_25C_A_N=3.csv: 數據量 = 7 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_2000k_Bm10-110mT_25C_C_N=3.csv: 數據量 = 10 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_2000k_Bm10-80mT_25C_A_N=3.csv: 數據量 = 7 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_2000k_Bm5-50mT_25C_A_N=3.csv: 數據量 = 19 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_2500k_Bm10-80mT_25C_A_N=3.csv: 數據量 = 7 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_3000k_Bm10-50mT_25C_A_N=3.csv: 數據量 = 4 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_3000k_Bm10-50mT_25C_C_N=3.csv: 數據量 = 4 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_3000k_Bm5-50mT_25C_A_N=3.csv: 數據量 = 9 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_500k_Bm10-100mT_25C_B_N=3.csv: 數據量 = 24 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_500k_Bm10-100mT_25C_C_N=3.csv: 數據量 = 24 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_500k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_500k_Bm5-100mT_25C_A_N=3.csv: 數據量 = 38 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_600k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_700k_Bm10-260mT_25C_A_N=3.csv: 數據量 = 17 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_800k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# 檔案 HITACHI_ML95S_R14-07-05_AC_sin_900k_Bm10-120mT_25C_A_N=3.csv: 數據量 = 11 點
# CSV 檔案數量 = 31
# 總數據量 = 460 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 N87R25:
# 檔案 TDK_N87_R25.3-14.8-10_AC_sin_100k_Bm10-300mT_25C_N=3.csv: 數據量 = 29 點
# 檔案 TDK_N87_R25.3-14.8-10_AC_sin_100k_Bm20-100mT_25C_N=3.1.csv: 數據量 = 16 點
# 檔案 TDK_N87_R25.3-14.8-10_AC_sin_100k_Bm20-100mT_25C_N=3.csv: 數據量 = 16 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_1000k_dB100mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_1000k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_1000k_dB50mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_1000k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB100mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB150mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB150mT_9-79Am_25C_N=3.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB50mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_100k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB100mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB150mT_9-79Am_25C_N=3.1.csv: 數據量 = 9 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB150mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB50mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_pulse_500k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_1000k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_1000k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB100mT_0-79Am_25C_N=3.1.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB100mT_0-79Am_25C_N=3.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB100mT_26-213Am_25C_N=8.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB100mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB150mT_0-79Am_25C_N=3.1.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB150mT_0-79Am_25C_N=3.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB150mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB200mT_0-79Am_25C_N=3.1.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB200mT_0-79Am_25C_N=3.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB50mT_0-79Am_25C_N=3.1.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB50mT_0-79Am_25C_N=3.csv: 數據量 = 8 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB50mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_100k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB100mT_26-213Am_25C_N=8.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB100mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB150mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB50mT_9-79Am_25C_N=3.1.csv: 數據量 = 7 點
# 檔案 TDK_N87_R25.3-14.8-10_DC_sin_500k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# CSV 檔案數量 = 41
# 總數據量 = 338 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 N87R42:
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_pulse_100k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_pulse_200k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_pulse_300k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_pulse_500k_Bm20-80mT_25C_N=10.csv: 數據量 = 6 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_pulse_50k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_100k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_10k_Bm10-500mT_25C_N=10.csv: 數據量 = 39 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_200k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_300k_Bm20-110mT_25C_N=10.csv: 數據量 = 9 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_300k_Bm20-90mT_25C_N=10.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_500k_Bm20-50mT_25C_N=10.csv: 數據量 = 3 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_500k_Bm20-60mT_25C_N=10.csv: 數據量 = 4 點
# 檔案 TDK_N87_R41.8-26.2-12.5_AC_sin_50k_Bm20-120mT_25C_N=10.csv: 數據量 = 10 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_1000k_dB100mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_1000k_dB150mT_9-50Am_25C_N=3.csv: 數據量 = 4 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_100k_dB150mT_9-79Am_25C_N=10.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_100k_dB150mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_100k_dB50mT_9-79Am_25C_N=10.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_100k_dB50mT_9-79Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_500k_dB100mT_9-80Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_500k_dB150mT_9-80Am_25C_N=3.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_500k_dB50mT_9-79Am_25C_N=10.csv: 數據量 = 7 點
# 檔案 TDK_N87_R41.8-26.2-12.5_DC_sin_500k_dB50mT_9-80Am_25C_N=3.csv: 數據量 = 7 點
# CSV 檔案數量 = 23
# 總數據量 = 205 點
# 無數據量為 0 行的檔案
#
#
# 子資料夾 R10KZ:
# 檔案 DMC_R10KZ_R25-15-8_AC_sin_100k_Bm200-280mT_100C_N=6.csv: 數據量 = 8 點
# 檔案 DMC_R10KZ_R25-15-8_AC_sin_100k_Bm50-250mT_100C_N=6.csv: 數據量 = 4 點
# CSV 檔案數量 = 2
# 總數據量 = 12 點
# 無數據量為 0 行的檔案
#
# ==================================================
# 總結報告
# ==================================================
# 子資料夾                 CSV 數量     數據量 (點)
# --------------------------------------------------
# 3C94                 1          14
# CH229060G            31         317
# CH229160G            4          80
# CH467160G            397        2898
# CS229060             12         143
# DMR28                2          12
# DMR53                18         215
# DMR70                1          6
# DMR91                2          58
# DMR96A_R12           12         139
# DMR96A_R49           9          74
# ML91S                20         270
# ML95S                31         460
# N87R25               41         338
# N87R42               23         205
# R10KZ                2          12
# --------------------------------------------------
# 總計 CSV 檔案數量 = 606
# 總計數據量為 0 行的檔案 = 0 個
# 總計數據量 = 5241 點
